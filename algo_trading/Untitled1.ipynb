# %%
# !pip3 install yahoofinancials
# Out:
# Requirement already satisfied: yahoofinancials in /home/lass/envs/algo_env/lib/python3.7/site-packages (1.5)
# Requirement already satisfied: pytz in /home/lass/envs/algo_env/lib/python3.7/site-packages (from yahoofinancials) (2019.2)
# Requirement already satisfied: beautifulsoup4 in /home/lass/envs/algo_env/lib/python3.7/site-packages (from yahoofinancials) (4.8.0)
# Requirement already satisfied: soupsieve>=1.2 in /home/lass/envs/algo_env/lib/python3.7/site-packages (from beautifulsoup4->yahoofinancials) (1.9.2)

# %%
from yahoofinancials import YahooFinancials

# %%
tech_stocks = ['AAPL', 'MSFT', 'INTC']
bank_stocks = ['WFC', 'BAC', 'C']
commodity_futures = ['GC=F', 'SI=F', 'CL=F']
cryptocurrencies = ['BTC-USD', 'ETH-USD', 'XRP-USD']
currencies = ['EURUSD=X', 'JPY=X', 'GBPUSD=X']
mutual_funds = ['PRLAX', 'QASGX', 'HISFX']
us_treasuries = ['^TNX', '^IRX', '^TYX']

# %%
yahoo_financials_tech = YahooFinancials(tech_stocks)
yahoo_financials_banks = YahooFinancials(bank_stocks)
yahoo_financials_commodities = YahooFinancials(commodity_futures)
yahoo_financials_cryptocurrencies = YahooFinancials(cryptocurrencies)
yahoo_financials_currencies = YahooFinancials(currencies)
yahoo_financials_mutualfunds = YahooFinancials(mutual_funds)
yahoo_financials_treasuries = YahooFinancials(us_treasuries)

# %%
tech_cash_flow_an = yahoo_financials_tech.get_financial_stmts('annual',
                                                             'cash')

# %%
tech_cash_flow_an
# Out:
# {'cashflowStatementHistory': {'AAPL': [{'2018-09-29': {'investments': 30845000000,
#      'changeToLiabilities': 9131000000,
#      'totalCashflowsFromInvestingActivities': 16066000000,
#      'netBorrowings': 432000000,
#      'totalCashFromFinancingActivities': -87876000000,
#      'changeToOperatingActivities': 30057000000,
#      'issuanceOfStock': 669000000,
#      'netIncome': 59531000000,
#      'changeInCash': 5624000000,
#      'repurchaseOfStock': -75265000000,
#      'totalCashFromOperatingActivities': 77434000000,
#      'depreciation': 10903000000,
#      'otherCashflowsFromInvestingActivities': -745000000,
#      'dividendsPaid': -13712000000,
#      'changeToInventory': 828000000,
#      'changeToAccountReceivables': -5322000000,
#      'changeToNetincome': -27694000000,
#      'capitalExpenditures': -13313000000}},
#    {'2017-09-30': {'investments': -33542000000,
#      'changeToLiabilities': 8340000000,
#      'totalCashflowsFromInvestingActivities': -46446000000,
#      'netBorrowings': 29014000000,
#      'totalCashFromFinancingActivities': -17974000000,
#      'changeToOperatingActivities': -8447000000,
#      'issuanceOfStock': 555000000,
#      'netIncome': 48351000000,
#      'changeInCash': -195000000,
#      'repurchaseOfStock': -34774000000,
#      'totalCashFromOperatingActivities': 64225000000,
#      'depreciation': 10157000000,
#      'otherCashflowsFromInvestingActivities': -124000000,
#      'dividendsPaid': -12769000000,
#      'changeToInventory': -2723000000,
#      'changeToAccountReceivables': -2093000000,
#      'changeToNetincome': 10640000000,
#      'capitalExpenditures': -12451000000}},
#    {'2016-09-24': {'investments': -32022000000,
#      'changeToLiabilities': 563000000,
#      'totalCashflowsFromInvestingActivities': -45977000000,
#      'netBorrowings': 22057000000,
#      'totalCashFromFinancingActivities': -20890000000,
#      'changeToOperatingActivities': -902000000,
#      'issuanceOfStock': 495000000,
#      'netIncome': 45687000000,
#      'changeInCash': -636000000,
#      'repurchaseOfStock': -31292000000,
#      'totalCashFromOperatingActivities': 66231000000,
#      'depreciation': 10505000000,
#      'otherCashflowsFromInvestingActivities': -924000000,
#      'dividendsPaid': -12150000000,
#      'changeToInventory': 217000000,
#      'changeToAccountReceivables': 527000000,
#      'changeToNetincome': 9634000000,
#      'capitalExpenditures': -12734000000}},
#    {'2015-09-26': {'investments': -44417000000,
#      'changeToLiabilities': 6043000000,
#      'totalCashflowsFromInvestingActivities': -56274000000,
#      'netBorrowings': 29305000000,
#      'totalCashFromFinancingActivities': -17716000000,
#      'changeToOperatingActivities': 5040000000,
#      'issuanceOfStock': 543000000,
#      'netIncome': 53394000000,
#      'changeInCash': 7276000000,
#      'repurchaseOfStock': -36752000000,
#      'totalCashFromOperatingActivities': 81266000000,
#      'depreciation': 11257000000,
#      'otherCashflowsFromInvestingActivities': -26000000,
#      'dividendsPaid': -11561000000,
#      'changeToInventory': -238000000,
#      'changeToAccountReceivables': 417000000,
#      'otherCashflowsFromFinancingActivities': 749000000,
#      'changeToNetincome': 5353000000,
#      'capitalExpenditures': -11247000000}}],
#   'MSFT': [{'2019-06-30': {'investments': 540000000,
#      'changeToLiabilities': 4694000000,
#      'totalCashflowsFromInvestingActivities': -15773000000,
#      'netBorrowings': -4000000000,
#      'totalCashFromFinancingActivities': -36887000000,
#      'changeToOperatingActivities': -1542000000,
#      'issuanceOfStock': 1142000000,
#      'netIncome': 39240000000,
#      'changeInCash': -590000000,
#      'repurchaseOfStock': -19543000000,
#      'effectOfExchangeRate': -115000000,
#      'totalCashFromOperatingActivities': 52185000000,
#      'depreciation': 11682000000,
#      'dividendsPaid': -13811000000,
#      'changeToInventory': 597000000,
#      'changeToAccountReceivables': -2812000000,
#      'otherCashflowsFromFinancingActivities': -675000000,
#      'changeToNetincome': -2603000000,
#      'capitalExpenditures': -13925000000}},
#    {'2018-06-30': {'investments': 6557000000,
#      'changeToLiabilities': 7070000000,
#      'totalCashflowsFromInvestingActivities': -6061000000,
#      'netBorrowings': -10201000000,
#      'totalCashFromFinancingActivities': -33590000000,
#      'changeToOperatingActivities': -459000000,
#      'issuanceOfStock': 1002000000,
#      'netIncome': 16571000000,
#      'changeInCash': 4283000000,
#      'repurchaseOfStock': -10721000000,
#      'effectOfExchangeRate': 50000000,
#      'totalCashFromOperatingActivities': 43884000000,
#      'depreciation': 9900000000,
#      'otherCashflowsFromInvestingActivities': -98000000,
#      'dividendsPaid': -12699000000,
#      'changeToInventory': -465000000,
#      'changeToAccountReceivables': -3862000000,
#      'otherCashflowsFromFinancingActivities': -971000000,
#      'changeToNetincome': -3108000000,
#      'capitalExpenditures': -11632000000}},
#    {'2017-06-30': {'investments': -12511000000,
#      'changeToLiabilities': 3901000000,
#      'totalCashflowsFromInvestingActivities': -46781000000,
#      'netBorrowings': 31459000000,
#      'totalCashFromFinancingActivities': 8408000000,
#      'changeToOperatingActivities': 349000000,
#      'issuanceOfStock': 772000000,
#      'netIncome': 25489000000,
#      'changeInCash': 1153000000,
#      'repurchaseOfStock': -11788000000,
#      'effectOfExchangeRate': 19000000,
#      'totalCashFromOperatingActivities': 39507000000,
#      'depreciation': 7800000000,
#      'otherCashflowsFromInvestingActivities': -197000000,
#      'dividendsPaid': -11845000000,
#      'changeToInventory': 50000000,
#      'changeToAccountReceivables': -1216000000,
#      'otherCashflowsFromFinancingActivities': -190000000,
#      'changeToNetincome': 1287000000,
#      'capitalExpenditures': -8129000000}},
#    {'2016-06-30': {'investments': -14417000000,
#      'changeToLiabilities': 2653000000,
#      'totalCashflowsFromInvestingActivities': -23950000000,
#      'netBorrowings': 18283000000,
#      'totalCashFromFinancingActivities': -8393000000,
#      'changeToOperatingActivities': -2907000000,
#      'issuanceOfStock': 668000000,
#      'netIncome': 20539000000,
#      'changeInCash': 915000000,
#      'repurchaseOfStock': -15969000000,
#      'effectOfExchangeRate': -67000000,
#      'totalCashFromOperatingActivities': 33325000000,
#      'depreciation': 5878000000,
#      'otherCashflowsFromInvestingActivities': 203000000,
#      'dividendsPaid': -11006000000,
#      'changeToInventory': 600000000,
#      'changeToAccountReceivables': 562000000,
#      'otherCashflowsFromFinancingActivities': -369000000,
#      'changeToNetincome': 6229000000,
#      'capitalExpenditures': -8343000000}}],
#   'INTC': [{'2018-12-29': {'investments': 3856000000,
#      'changeToLiabilities': 1578000000,
#      'totalCashflowsFromInvestingActivities': -11239000000,
#      'netBorrowings': -2143000000,
#      'totalCashFromFinancingActivities': -18607000000,
#      'changeToOperatingActivities': -219000000,
#      'issuanceOfStock': 555000000,
#      'netIncome': 21053000000,
#      'changeInCash': -414000000,
#      'repurchaseOfStock': -10730000000,
#      'totalCashFromOperatingActivities': 29432000000,
#      'depreciation': 9085000000,
#      'otherCashflowsFromInvestingActivities': -272000000,
#      'dividendsPaid': -5541000000,
#      'changeToInventory': -214000000,
#      'changeToAccountReceivables': -1714000000,
#      'otherCashflowsFromFinancingActivities': -748000000,
#      'changeToNetincome': -285000000,
#      'capitalExpenditures': -15181000000}},
#    {'2017-12-30': {'investments': 6661000000,
#      'changeToLiabilities': 1296000000,
#      'totalCashflowsFromInvestingActivities': -15762000000,
#      'netBorrowings': -352000000,
#      'totalCashFromFinancingActivities': -8475000000,
#      'changeToOperatingActivities': -477000000,
#      'issuanceOfStock': 770000000,
#      'netIncome': 9601000000,
#      'changeInCash': -2127000000,
#      'repurchaseOfStock': -3615000000,
#      'totalCashFromOperatingActivities': 22110000000,
#      'depreciation': 8129000000,
#      'otherCashflowsFromInvestingActivities': 730000000,
#      'dividendsPaid': -5072000000,
#      'changeToInventory': -1300000000,
#      'changeToAccountReceivables': -781000000,
#      'otherCashflowsFromFinancingActivities': -206000000,
#      'changeToNetincome': 412000000,
#      'capitalExpenditures': -11778000000}},
#    {'2016-12-31': {'investments': -1990000000,
#      'changeToLiabilities': 182000000,
#      'totalCashflowsFromInvestingActivities': -25817000000,
#      'netBorrowings': 1219000000,
#      'totalCashFromFinancingActivities': -5739000000,
#      'changeToOperatingActivities': 685000000,
#      'issuanceOfStock': 1108000000,
#      'netIncome': 10316000000,
#      'changeInCash': -9748000000,
#      'repurchaseOfStock': -2587000000,
#      'totalCashFromOperatingActivities': 21808000000,
#      'depreciation': 7790000000,
#      'otherCashflowsFromInvestingActivities': 1268000000,
#      'dividendsPaid': -4925000000,
#      'changeToInventory': 119000000,
#      'changeToAccountReceivables': 65000000,
#      'otherCashflowsFromFinancingActivities': -554000000,
#      'changeToNetincome': 1269000000,
#      'capitalExpenditures': -9625000000}},
#    {'2015-12-26': {'investments': -125000000,
#      'changeToLiabilities': -312000000,
#      'totalCashflowsFromInvestingActivities': -8183000000,
#      'netBorrowings': 9476000000,
#      'totalCashFromFinancingActivities': 1912000000,
#      'changeToOperatingActivities': -194000000,
#      'issuanceOfStock': 866000000,
#      'netIncome': 11420000000,
#      'changeInCash': 12747000000,
#      'repurchaseOfStock': -3001000000,
#      'totalCashFromOperatingActivities': 19018000000,
#      'depreciation': 8711000000,
#      'otherCashflowsFromInvestingActivities': 181000000,
#      'dividendsPaid': -4556000000,
#      'changeToInventory': -764000000,
#      'changeToAccountReceivables': -355000000,
#      'otherCashflowsFromFinancingActivities': -873000000,
#      'changeToNetincome': 126000000,
#      'capitalExpenditures': -7326000000}}]}}
